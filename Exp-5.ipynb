# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import *
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('DecisionTreeRegressor.csv')
df
# Out:
#      outlook  temp humidity    wind  Score
# 0      sunny   hot     high    weak     25
# 1      sunny   hot     high  strong     30
# 2   overcast   hot     high    weak     46
# 3      rainy  mild     high    weak     45
# 4      rainy  cool   normal    weak     52
# 5      rainy  cool   normal  strong     23
# 6   overcast  cool   normal  strong     43
# 7      sunny  mild     high    weak     35
# 8      sunny  cool   normal    weak     38
# 9      rainy  mild   normal    weak     46
# 10     sunny  mild   normal  strong     48
# 11  overcast  mild     high  strong     52
# 12  overcast   hot   normal    weak     44
# 13     rainy  mild     high  strong     30

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['outlook'] = le.fit_transform(df[['outlook']])
df['temp'] = le.fit_transform(df[['temp']])
df['humidity'] = le.fit_transform(df[['humidity']])
df['wind'] = le.fit_transform(df[['wind']])
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df
# Out:
#     outlook  temp  humidity  wind  Score
# 0         2     1         0     1     25
# 1         2     1         0     0     30
# 2         0     1         0     1     46
# 3         1     2         0     1     45
# 4         1     0         1     1     52
# 5         1     0         1     0     23
# 6         0     0         1     0     43
# 7         2     2         0     1     35
# 8         2     0         1     1     38
# 9         1     2         1     1     46
# 10        2     2         1     0     48
# 11        0     2         0     0     52
# 12        0     1         1     1     44
# 13        1     2         0     0     30

# %%
x = df.iloc[:, : -1]
y = df.iloc[:, -1:]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
plt.figure(figsize=(20, 20))
plot_tree(dt, filled=True, feature_names=x.columns, rounded=True)
plt.show()

# %%
y_pred = dt.predict(x_test)

# %%
from sklearn.metrics import *

print(f"R2 Score: {r2_score(y_test, dt.predict(x_test))}")
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
print(f"Mean Absolute Error: {mean_absolute_error(y_test, y_pred)}")
print(f"RootMean Squared Error: {np.sqrt(mean_squared_error(y_test, y_pred))}")
# Out:
# R2 Score: 0.5398009950248757
# Mean Squared Error: 61.666666666666664
# Mean Absolute Error: 7.0
# RootMean Squared Error: 7.852812659593164

# %%
dt.score(x_test, y_test)
# Out:
# 0.5398009950248757
